# %% [markdown]
# deepfaceを用いて顔画像から感情分析

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

result = DeepFace.analyze(img_path = "veneers-1-300x200.jpg", actions = ['emotion'])

data = result[0]

emotions = data["emotion"]

print(data)

# データ分解
labels = list(emotions.keys())
values = list(emotions.values())

# グラフ作成
plt.figure()
plt.bar(labels, values)

plt.title("Emotion Analysis")
plt.xlabel("Emotion")
plt.ylabel("Percentage")

plt.show()
# Out:
# {'emotion': {'angry': 6.233775995401203e-09, 'disgust': 2.2175398659733938e-15, 'fear': 4.5848338146858847e-10, 'happy': 93.53663921356201, 'sad': 6.453079737234191e-08, 'surprise': 0.0038556387153221294, 'neutral': 6.4595043659210205}, 'dominant_emotion': 'happy', 'region': {'x': 112, 'y': 40, 'w': 109, 'h': 109, 'left_eye': (184, 85), 'right_eye': (143, 85)}, 'face_confidence': 0.93}
